# %%
# Factory-to-Customer Shipping Route Efficiency Analysis for Nassau Candy Distributor

# %%
# Import required libraries
import pandas as pd
import numpy as np
import plotly.express as px
import plotly.graph_objects as go

# %%
# Load data
df = pd.read_csv('/content/Nassau Candy Distributor.csv')

# %%
# Factory locations
FACTORIES = {
    "Lot's O' Nuts":      {"lat": 32.881893, "lon": -111.768036},
    "Wicked Choccy's":    {"lat": 32.076176, "lon": -81.088371},
    "Sugar Shack":        {"lat": 48.11914,  "lon": -96.18115},
    "Secret Factory":     {"lat": 41.446333, "lon": -90.565487},
    "The Other Factory":  {"lat": 35.1175,   "lon": -89.971107},
}

# Product to factory mapping
PRODUCT_FACTORY = {
    "Wonka Bar - Nutty Crunch Surprise":   "Lot's O' Nuts",
    "Wonka Bar - Fudge Mallows":           "Lot's O' Nuts",
    "Wonka Bar -Scrumdiddlyumptious":      "Lot's O' Nuts",
    "Wonka Bar - Milk Chocolate":          "Wicked Choccy's",
    "Wonka Bar - Triple Dazzle Caramel":   "Wicked Choccy's",
    "Laffy Taffy":                         "Sugar Shack",
    "SweeTARTS":                           "Sugar Shack",
    "Nerds":                               "Sugar Shack",
    "Fun Dip":                             "Sugar Shack",
    "Fizzy Lifting Drinks":                "Sugar Shack",
    "Everlasting Gobstopper":              "Secret Factory",
    "Lickable Wallpaper":                  "Secret Factory",
    "Wonka Gum":                           "Secret Factory",
    "Hair Toffee":                         "The Other Factory",
    "Kazookles":                           "The Other Factory",
}

# %%
# Show the first 5 values
df.head()
# Out:
#    Row ID                      Order ID  Order Date   Ship Date  \
# 0       1  US-2021-103800-CHO-MIL-31000  03-01-2024  30-06-2026
# 1       2  US-2021-112326-CHO-TRI-54000  04-01-2024  01-07-2026
# 2       3  US-2021-112326-CHO-NUT-13000  04-01-2024  01-07-2026
# 3       4  US-2021-112326-CHO-SCR-58000  04-01-2024  01-07-2026
# 4       5  US-2021-141817-CHO-TRI-54000  05-01-2024  05-07-2026
#
#         Ship Mode  Customer ID Country/Region          City State/Province  \
# 0  Standard Class       103800  United States       Houston          Texas
# 1  Standard Class       112326  United States    Naperville       Illinois
# 2  Standard Class       112326  United States    Naperville       Illinois
# 3  Standard Class       112326  United States    Naperville       Illinois
# 4  Standard Class       141817  United States  Philadelphia   Pennsylvania
#
#   Postal Code   Division    Region     Product ID  \
# 0       77095  Chocolate  Interior  CHO-MIL-31000
# 1       60540  Chocolate  Interior  CHO-TRI-54000
# 2       60540  Chocolate  Interior  CHO-NUT-13000
# 3       60540  Chocolate  Interior  CHO-SCR-58000
# 4       19143  Chocolate  Atlantic  CHO-TRI-54000
#
#                         Product Name  Sales  Units  Gross Profit  Cost
# 0         Wonka Bar - Milk Chocolate   6.50      2          4.22  2.28
# 1  Wonka Bar - Triple Dazzle Caramel   7.50      2          4.90  2.60
# 2  Wonka Bar - Nutty Crunch Surprise  10.47      3          7.47  3.00
# 3     Wonka Bar -Scrumdiddlyumptious  10.80      3          7.50  3.30
# 4  Wonka Bar - Triple Dazzle Caramel  11.25      3          7.35  3.90

# %%
# Get info
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10194 entries, 0 to 10193
# Data columns (total 18 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Row ID          10194 non-null  int64
#  1   Order ID        10194 non-null  object
#  2   Order Date      10194 non-null  object
#  3   Ship Date       10194 non-null  object
#  4   Ship Mode       10194 non-null  object
#  5   Customer ID     10194 non-null  int64
#  6   Country/Region  10194 non-null  object
#  7   City            10194 non-null  object
#  8   State/Province  10194 non-null  object
#  9   Postal Code     10194 non-null  object
#  10  Division        10194 non-null  object
#  11  Region          10194 non-null  object
#  12  Product ID      10194 non-null  object
#  13  Product Name    10194 non-null  object
#  14  Sales           10194 non-null  float64
#  15  Units           10194 non-null  int64
#  16  Gross Profit    10194 non-null  float64
#  17  Cost            10194 non-null  float64
# dtypes: float64(3), int64(3), object(12)
# memory usage: 1.4+ MB

# %%
# Validate date format

# %%
# YYYY-MM-DD (standard format) Order Date
df['Order Date'] = pd.to_datetime(df['Order Date'], format='%d-%m-%Y', errors='coerce')

# %%
# YYYY-MM-DD (standard format) Ship Date
df['Ship Date'] = pd.to_datetime(df['Ship Date'], format='%d-%m-%Y', errors='coerce')

# %%
# Identify Invalid Dates
invalid_dates = df[df['Order Date'].isnull()]

print("Invalid rows:")
print(invalid_dates)
# Out:
# Invalid rows:
# Empty DataFrame
# Columns: [Row ID, Order ID, Order Date, Ship Date, Ship Mode, Customer ID, Country/Region, City, State/Province, Postal Code, Division, Region, Product ID, Product Name, Sales, Units, Gross Profit, Cost]
# Index: []

# %%
# Count invalid entries
print("Total invalid dates:", df['Order Date'].isnull().sum())
# Out:
# Total invalid dates: 0

# %%
# Drop invalid entries
df = df.dropna(subset=['Order Date'])

# %%
# Calculate Lead Time
df['Lead Time'] = (df['Ship Date'] - df['Order Date']).dt.days
df = df[df['Lead Time'] >= 0].copy()

# Add Factory and Route
df['Factory'] = df['Product Name'].map(PRODUCT_FACTORY)
df['Route'] = df['Factory'] + ' → ' + df['Country/Region'] + ' - ' + df['State/Province']
df['Month'] = df['Order Date'].dt.to_period('M').astype(str)

# Clean text columns
for col in ['Country/Region', 'State/Province', 'City']:
    df[col] = df[col].str.strip().str.title()

# Verify data
print("Data shape:", df.shape)
print("Lead Time stats:")
print(df['Lead Time'].describe())
# Out:
# Data shape: (10194, 22)
# Lead Time stats:
# count    10194.000000
# mean      1320.841868
# std        262.444892
# min        904.000000
# 25%       1271.000000
# 50%       1274.000000
# 75%       1638.000000
# max       1642.000000
# Name: Lead Time, dtype: float64

# %%
# Extract features
df['Year'] = df['Order Date'].dt.year
df['Month'] = df['Order Date'].dt.month
df['Day'] = df['Order Date'].dt.day

# %%
# Calculate Lead Time
df['Shipping Lead Time'] = (df['Ship Date'] - df['Order Date']).dt.days

# %%
# Verify output
print(df[['Order Date', 'Ship Date', 'Shipping Lead Time']].head())
# Out:
#   Order Date  Ship Date  Shipping Lead Time
# 0 2024-01-03 2026-06-30                 909
# 1 2024-01-04 2026-07-01                 909
# 2 2024-01-04 2026-07-01                 909
# 3 2024-01-04 2026-07-01                 909
# 4 2024-01-05 2026-07-05                 912

# %%
# Validate lead time
df = df[(df['Shipping Lead Time'].notnull()) & (df['Shipping Lead Time'] >= 0)]

# %%
# Verify it
print(df['Shipping Lead Time'].isnull().sum())
# Out:
# 0

# %%
# Check missing shipment records
missing_ship = df[df['Ship Date'].isnull()]

print("Missing shipment records:", missing_ship.shape[0])
missing_ship.head()
# Out:
# Missing shipment records: 0
# Empty DataFrame
# Columns: [Row ID, Order ID, Order Date, Ship Date, Ship Mode, Customer ID, Country/Region, City, State/Province, Postal Code, Division, Region, Product ID, Product Name, Sales, Units, Gross Profit, Cost, Lead Time, Factory, Route, Month, Year, Day, Shipping Lead Time]
# Index: []
#
# [0 rows x 25 columns]

# %%
# Cleane data columns
for col in ['Country/Region', 'State/Province', 'City']:
    df[col] = df[col].str.strip()      # remove spaces
    df[col] = df[col].str.title()     # standard case

# %%
# Clean unrealistic values
df = df[df['Shipping Lead Time'] >= 0]

# %%
# Check for the null values
print(df['Shipping Lead Time'].isnull().sum())
# Out:
# 0

# %%
# Quick sanity check
print("Average Lead Time:", df['Shipping Lead Time'].mean())
print("Max Lead Time:", df['Shipping Lead Time'].max())
# Out:
# Average Lead Time: 1320.8418677653522
# Max Lead Time: 1642

# %%
# Create Routes Factory -> Region
df['Route_Region'] = 'Factory → ' + df['Country/Region'] + ' - ' + df['Region']

# %%
# Create Routes Factory -> State
df['Route_State'] = 'Factory → ' + df['Country/Region'] + ' - ' + df['State/Province']

# %%
# Verify it
df[['Route_Region', 'Route_State']].head()
# Out:
#                          Route_Region                             Route_State
# 0  Factory → United States - Interior         Factory → United States - Texas
# 1  Factory → United States - Interior      Factory → United States - Illinois
# 2  Factory → United States - Interior      Factory → United States - Illinois
# 3  Factory → United States - Interior      Factory → United States - Illinois
# 4  Factory → United States - Atlantic  Factory → United States - Pennsylvania

# %%
# Check available modes
df['Ship Mode'].unique()
# Out:
# array(['Standard Class', 'First Class', 'Second Class', 'Same Day'],
#       dtype=object)

# %%
# Group by ship mode
df.groupby('Ship Mode').size()
# Out:
# Ship Mode
# First Class       1548
# Same Day           547
# Second Class      1979
# Standard Class    6120
# dtype: int64

# %%
df['Ship Mode'].value_counts()
# Out:
# Ship Mode
# Standard Class    6120
# Second Class      1979
# First Class       1548
# Same Day           547
# Name: count, dtype: int64

# %%
# Aggrigation by route Region

route_region_summary = df.groupby('Route_Region').agg(
    Total_Shipments=('Route_Region', 'count'),
    Avg_Lead_Time=('Shipping Lead Time', 'mean'),
    Lead_Time_Variability=('Shipping Lead Time', 'std')
).reset_index()

# %%
# Aggrigation by route state

route_state_summary = df.groupby('Route_State').agg(
    Total_Shipments=('Route_State', 'count'),
    Avg_Lead_Time=('Shipping Lead Time', 'mean'),
    Lead_Time_Variability=('Shipping Lead Time', 'std')
).reset_index()

# %%
route_region_summary.head()
# Out:
#                          Route_Region  Total_Shipments  Avg_Lead_Time  \
# 0         Factory → Canada - Atlantic              138    1275.992754
# 1         Factory → Canada - Interior               12    1455.333333
# 2          Factory → Canada - Pacific               50    1288.540000
# 3  Factory → United States - Atlantic             2848    1325.010534
# 4      Factory → United States - Gulf             1620    1311.374691
#
#    Lead_Time_Variability
# 0             291.093195
# 1             191.139803
# 2             295.004131
# 3             254.588321
# 4             264.727855

# %%
route_state_summary.head()
# Out:
#                                     Route_State  Total_Shipments  \
# 0                    Factory → Canada - Alberta               26
# 1           Factory → Canada - British Columbia               22
# 2                   Factory → Canada - Manitoba               12
# 3              Factory → Canada - New Brunswick                8
# 4  Factory → Canada - Newfoundland And Labrador                6
#
#    Avg_Lead_Time  Lead_Time_Variability
# 0    1274.076923             292.400673
# 1    1290.318182             308.425091
# 2    1455.333333             191.139803
# 3    1273.250000             276.292159
# 4    1216.166667             357.447292

# %%
# Key Performance Indicators
total_shipments = len(df)
avg_lead = df['Shipping Lead Time'].mean()
median_lead = df['Shipping Lead Time'].median()
delay_threshold = 7  # example
delayed = len(df[df['Shipping Lead Time'] > delay_threshold])
delay_pct = delayed / total_shipments * 100
total_sales = df['Sales'].sum()
total_profit = df['Gross Profit'].sum()
efficiency_score = 100 - (avg_lead / df['Shipping Lead Time'].max() * 100) if df['Shipping Lead Time'].max() > 0 else 100

print("=== Key Performance Indicators ===")
print(f"Total Shipments: {total_shipments:,}")
print(f"Average Lead Time: {avg_lead:.1f} days")
print(f"Median Lead Time: {median_lead:.1f} days")
print(f"Delayed Shipments (>{delay_threshold}d): {delayed:,} ({delay_pct:.1f}%)")
print(f"Total Sales: ${total_sales:,.0f}")
print(f"Total Gross Profit: ${total_profit:,.0f}")
print(f"Profit Margin: {(total_profit / total_sales * 100):.1f}%" if total_sales > 0 else "N/A")
print(f"Efficiency Score: {efficiency_score:.1f}%")
# Out:
# === Key Performance Indicators ===
# Total Shipments: 10,194
# Average Lead Time: 1320.8 days
# Median Lead Time: 1274.0 days
# Delayed Shipments (>7d): 10,194 (100.0%)
# Total Sales: $141,784
# Total Gross Profit: $93,443
# Profit Margin: 65.9%
# Efficiency Score: 19.6%

# %%
# Rank by Region

route_region_ranked = route_region_summary.sort_values(by='Avg_Lead_Time')

# %%
# Rank by State

route_state_ranked = route_state_summary.sort_values(by='Avg_Lead_Time')

# %%
# Top 10 fastest route
top_10_routes = route_state_ranked.head(10)

# %%
# Bottom 10 slowest
bottom_10_routes = route_state_ranked.tail(10)

# %%
top_10_routes
# Out:
#                                      Route_State  Total_Shipments  \
# 27               Factory → United States - Maine                8
# 4   Factory → Canada - Newfoundland And Labrador                6
# 36              Factory → United States - Nevada               39
# 54            Factory → United States - Virginia              224
# 6                     Factory → Canada - Ontario               58
# 52                Factory → United States - Utah               53
# 48      Factory → United States - South Carolina               42
# 26           Factory → United States - Louisiana               42
# 32         Factory → United States - Mississippi               53
# 45              Factory → United States - Oregon              124
#
#     Avg_Lead_Time  Lead_Time_Variability
# 27    1137.125000             189.733977
# 4     1216.166667             357.447292
# 36    1226.794872             239.772390
# 54    1229.125000             256.420396
# 6     1247.465517             272.269939
# 52    1253.000000             289.780554
# 48    1255.428571             241.749835
# 26    1263.785714             306.777550
# 32    1266.566038             263.148869
# 45    1267.709677             259.367642

# %%
bottom_10_routes
# Out:
#                                 Route_State  Total_Shipments  Avg_Lead_Time  \
# 50      Factory → United States - Tennessee              183    1391.486339
# 49   Factory → United States - South Dakota               12    1395.916667
# 7   Factory → Canada - Prince Edward Island               10    1420.300000
# 53        Factory → United States - Vermont               11    1438.909091
# 39     Factory → United States - New Mexico               37    1441.837838
# 23           Factory → United States - Iowa               30    1443.900000
# 2               Factory → Canada - Manitoba               12    1455.333333
# 9           Factory → Canada - Saskatchewan                2    1457.000000
# 42   Factory → United States - North Dakota                7    1637.857143
# 56  Factory → United States - West Virginia                4    1638.000000
#
#     Lead_Time_Variability
# 50             248.201971
# 49             360.350955
# 7              255.814190
# 53             190.999714
# 39             267.198066
# 23             229.801466
# 2              191.139803
# 9              258.801082
# 42               1.463850
# 56               2.000000

# %%
# Compare across ship modes

ship_mode_comparison = df.groupby('Ship Mode').agg(
    Avg_Lead_Time=('Shipping Lead Time', 'mean'),
    Total_Shipments=('Ship Mode', 'count')
).reset_index()

# %%
ship_mode_comparison
# Out:
#         Ship Mode  Avg_Lead_Time  Total_Shipments
# 0     First Class    1338.275840             1548
# 1        Same Day    1333.442413              547
# 2    Second Class    1323.845376             1979
# 3  Standard Class    1314.334641             6120

# %%
# High average lead time

avg_lead_time = df.groupby('State/Province')['Shipping Lead Time'].mean().sort_values(ascending=False)

avg_lead_time.head(10)
# Out:
# State/Province
# West Virginia           1638.000000
# North Dakota            1637.857143
# Saskatchewan            1457.000000
# Manitoba                1455.333333
# Iowa                    1443.900000
# New Mexico              1441.837838
# Vermont                 1438.909091
# Prince Edward Island    1420.300000
# South Dakota            1395.916667
# Tennessee               1391.486339
# Name: Shipping Lead Time, dtype: float64

# %%
# High volume + poor performance

# Shipment volume
volume = df.groupby('State/Province').size()

# Avg lead time (reuse)
performance = df.groupby('State/Province')['Shipping Lead Time'].mean()

# Combine both
region_perf = pd.DataFrame({
    'Volume': volume,
    'Avg_Lead_Time': performance
})

# Sort for bottleneck detection
region_perf = region_perf.sort_values(by=['Volume', 'Avg_Lead_Time'], ascending=False)

region_perf.head(10)
# Out:
#                 Volume  Avg_Lead_Time
# State/Province
# California        2001    1318.427286
# New York          1128    1324.493794
# Texas              985    1310.305584
# Pennsylvania       587    1324.199319
# Washington         506    1360.662055
# Illinois           492    1323.150407
# Ohio               469    1325.733475
# Florida            383    1311.396867
# Michigan           255    1300.560784
# North Carolina     249    1334.883534

# %%
# Congation-Prone Region

# Define delay threshold (example: >5 days)
delay_threshold = 5

# Delay flag
df['Delayed'] = df['Shipping Lead Time'] > delay_threshold

# Aggregation
congestion = df.groupby('State/Province').agg({
    'Shipping Lead Time': ['mean', 'std'],
    'Delayed': 'mean'
})

# Flatten columns
congestion.columns = ['Avg_Lead_Time', 'Std_Dev', 'Delay_Frequency']

# Sort by delay frequency
congestion = congestion.sort_values(by='Delay_Frequency', ascending=False)

congestion.head(10)
# Out:
#                       Avg_Lead_Time     Std_Dev  Delay_Frequency
# State/Province
# Alabama                 1291.278689  253.475320              1.0
# Alberta                 1274.076923  292.400673              1.0
# Arizona                 1309.214286  263.392440              1.0
# Arkansas                1285.733333  284.746266              1.0
# British Columbia        1290.318182  308.425091              1.0
# California              1318.427286  264.392878              1.0
# Colorado                1337.186813  249.676959              1.0
# Connecticut             1357.548780  271.682874              1.0
# Delaware                1269.750000  233.930669              1.0
# District Of Columbia    1347.700000  153.528897              1.0

# %%
# Average Lead Time by Ship Mode
ship_eff = df.groupby('Ship Mode')['Shipping Lead Time'].mean().sort_values()

ship_eff
# Out:
# Ship Mode
# Standard Class    1314.334641
# Second Class      1323.845376
# Same Day          1333.442413
# First Class       1338.275840
# Name: Shipping Lead Time, dtype: float64

# %%
# Extended

ship_mode_perf = df.groupby('Ship Mode').agg({
    'Shipping Lead Time': ['mean', 'std'],
    'Order Date': 'count'
})

ship_mode_perf.columns = ['Avg_Lead_Time', 'Std_Dev', 'Volume']

ship_mode_perf.sort_values(by='Avg_Lead_Time')
# Out:
#                 Avg_Lead_Time     Std_Dev  Volume
# Ship Mode
# Standard Class    1314.334641  262.400116    6120
# Second Class      1323.845376  261.813569    1979
# Same Day          1333.442413  253.813374     547
# First Class       1338.275840  265.632140    1548

# %%
# Division Analysis
division_analysis = df.groupby('Division').agg({
    'Shipping Lead Time': ['mean', 'std', 'count'],
    'Sales': 'sum',
    'Gross Profit': 'sum'
})
division_analysis.columns = ['Avg_Lead_Time', 'Std_Dev', 'Shipments', 'Total_Sales', 'Total_Profit']
division_analysis['Delay_Rate'] = df.assign(Delayed=df['Shipping Lead Time'] > delay_threshold).groupby('Division')['Delayed'].mean() * 100
division_analysis = division_analysis.round(2)

print("=== Division Analysis ===")
print(division_analysis)
# Out:
# === Division Analysis ===
#            Avg_Lead_Time  Std_Dev  Shipments  Total_Sales  Total_Profit  \
# Division
# Chocolate        1321.17   261.85       9844    131692.90      88824.62
# Other            1306.03   281.66        310      9663.25       4333.45
# Sugar            1355.65   254.87         40       427.48        284.73
#
#            Delay_Rate
# Division
# Chocolate       100.0
# Other           100.0
# Sugar           100.0

# %% [markdown]
# # Key Performance Indicators (KPIs)

# %%
fig_hist = px.histogram(df, x='Shipping Lead Time', nbins=30,
                        title='Distribution of Shipping Lead Time (Plotly)',
                        color_discrete_sequence=['purple'])
fig_hist.update_layout(plot_bgcolor='rgba(0,0,0,0)', paper_bgcolor='rgba(0,0,0,0)')
fig_hist.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="3fd76060-51cd-4bb7-b9b7-f16c67cbd798" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3fd76060-51cd-4bb7-b9b7-f16c67cbd798")) {                    Plotly.newPlot(                        "3fd76060-51cd-4bb7-b9b7-f16c67cbd798",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Shipping Lead Time=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"purple","pattern":{"shape":""}},"name":"","nbinsx":30,"offsetgroup":"","orientation":"v","showlegend":false,"x":[909,909,909,909,912,909,909,906,909,909,909,907,909,909,910,910,909,909,910,910,908,910,908,910,910,907,907,907,910,907,910,907,906,907,907,907,907,907,908,906,906,906,906,911,911,911,911,910,911,911,911,911,911,911,911,911,910,911,911,911,907,908,908,908,908,908,909,910,908,910,910,908,910,910,910,910,910,911,911,911,911,910,910,907,907,912,909,912,908,908,909,909,909,909,908,908,908,908,910,906,909,909,909,909,909,909,909,909,909,911,909,910,909,909,909,910,910,912,905,911,911,909,911,909,907,909,909,911,911,909,908,908,909,908,910,908,908,908,910,908,910,908,910,908,909,908,908,908,909,909,909,909,909,909,904,907,907,907,907,907,909,905,909,909,905,908,909,905,911,908,911,909,906,908,909,906,907,906,906,909,909,909,908,909,909,908,908,907,909,909,909,907,908,908,908,908,908,909,908,908,908,911,908,904,911,911,908,908,911,911,908,904,904,908,908,908,907,907,909,909,910,909,909,909,910,910,909,909,906,906,906,906,906,906,906,908,908,908,908,908,908,908,908,908,908,908,908,904,908,908,908,907,907,907,909,908,911,909,909,909,909,909,909,908,908,909,910,909,909,908,908,909,906,905,908,906,909,910,909,906,904,909,904,908,904,908,904,909,908,909,909,909,909,910,910,908,908,910,910,909,909,909,909,909,905,909,908,908,908,908,908,906,906,908,908,906,908,906,906,906,906,908,908,910,910,910,906,908,908,908,910,910,906,910,908,906,907,909,904,909,904,908,908,908,911,909,911,908,909,906,906,911,906,906,911,911,909,909,910,909,909,909,909,908,908,908,909,908,904,904,908,908,909,908,909,908,909,908,909,906,908,908,909,906,906,906,908,909,906,906,908,908,908,908,905,907,909,909,909,908,908,908,911,908,911,908,909,909,909,909,909,909,909,909,906,908,906,909,906,908,909,906,906,906,904,906,911,911,906,904,907,907,905,908,905,907,908,906,906,908,908,909,909,908,909,909,909,909,909,909,909,909,909,906,904,904,904,904,910,910,908,909,908,909,909,909,909,909,909,909,911,908,908,910,909,909,907,909,910,906,906,910,906,908,910,911,908,908,906,906,908,910,908,907,906,906,906,906,906,906,906,908,908,908,906,909,908,906,909,908,906,906,909,908,909,909,909,911,911,908,908,908,908,908,908,908,910,908,908,908,908,908,909,909,907,909,908,908,904,907,904,909,909,908,909,909,910,906,911,906,910,906,908,906,909,909,909,909,909,909,909,909,909,909,909,909,909,909,908,909,908,908,907,908,908,907,907,909,909,909,909,909,909,907,910,910,909,910,908,910,909,908,907,908,910,909,909,909,908,909,906,909,908,908,909,911,909,908,911,908,908,909,909,909,908,910,910,910,910,904,910,909,909,909,908,908,908,907,910,909,906,908,911,911,908,908,908,908,908,908,908,906,907,908,908,907,908,904,904,908,907,906,908,908,904,906,907,908,909,909,904,906,906,907,909,907,907,909,908,907,906,906,906,908,908,908,908,908,908,910,908,908,911,908,910,907,906,909,910,908,904,908,908,909,908,908,908,907,909,907,909,907,907,911,910,907,907,907,904,904,907,910,906,908,908,906,908,908,909,909,909,908,908,910,909,910,908,908,908,908,908,908,907,908,907,908,907,910,908,909,908,910,909,908,907,908,908,907,908,908,908,910,908,907,910,911,910,908,908,908,908,904,909,909,909,909,909,909,908,906,908,907,904,906,906,906,906,907,906,907,904,908,907,908,908,9 ...

# %%
fig_box = px.box(df, x='Shipping Lead Time',
                 title='Distribution of Shipping Lead Time (Boxplot - Plotly)',
                 color_discrete_sequence=['blue'])
fig_box.update_layout(plot_bgcolor='rgba(0,0,0,0)', paper_bgcolor='rgba(0,0,0,0)')
fig_box.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="999c829c-2ecb-4bca-b214-da4b6071c525" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("999c829c-2ecb-4bca-b214-da4b6071c525")) {                    Plotly.newPlot(                        "999c829c-2ecb-4bca-b214-da4b6071c525",                        [{"alignmentgroup":"True","hovertemplate":"Shipping Lead Time=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"blue"},"name":"","notched":false,"offsetgroup":"","orientation":"h","showlegend":false,"x":[909,909,909,909,912,909,909,906,909,909,909,907,909,909,910,910,909,909,910,910,908,910,908,910,910,907,907,907,910,907,910,907,906,907,907,907,907,907,908,906,906,906,906,911,911,911,911,910,911,911,911,911,911,911,911,911,910,911,911,911,907,908,908,908,908,908,909,910,908,910,910,908,910,910,910,910,910,911,911,911,911,910,910,907,907,912,909,912,908,908,909,909,909,909,908,908,908,908,910,906,909,909,909,909,909,909,909,909,909,911,909,910,909,909,909,910,910,912,905,911,911,909,911,909,907,909,909,911,911,909,908,908,909,908,910,908,908,908,910,908,910,908,910,908,909,908,908,908,909,909,909,909,909,909,904,907,907,907,907,907,909,905,909,909,905,908,909,905,911,908,911,909,906,908,909,906,907,906,906,909,909,909,908,909,909,908,908,907,909,909,909,907,908,908,908,908,908,909,908,908,908,911,908,904,911,911,908,908,911,911,908,904,904,908,908,908,907,907,909,909,910,909,909,909,910,910,909,909,906,906,906,906,906,906,906,908,908,908,908,908,908,908,908,908,908,908,908,904,908,908,908,907,907,907,909,908,911,909,909,909,909,909,909,908,908,909,910,909,909,908,908,909,906,905,908,906,909,910,909,906,904,909,904,908,904,908,904,909,908,909,909,909,909,910,910,908,908,910,910,909,909,909,909,909,905,909,908,908,908,908,908,906,906,908,908,906,908,906,906,906,906,908,908,910,910,910,906,908,908,908,910,910,906,910,908,906,907,909,904,909,904,908,908,908,911,909,911,908,909,906,906,911,906,906,911,911,909,909,910,909,909,909,909,908,908,908,909,908,904,904,908,908,909,908,909,908,909,908,909,906,908,908,909,906,906,906,908,909,906,906,908,908,908,908,905,907,909,909,909,908,908,908,911,908,911,908,909,909,909,909,909,909,909,909,906,908,906,909,906,908,909,906,906,906,904,906,911,911,906,904,907,907,905,908,905,907,908,906,906,908,908,909,909,908,909,909,909,909,909,909,909,909,909,906,904,904,904,904,910,910,908,909,908,909,909,909,909,909,909,909,911,908,908,910,909,909,907,909,910,906,906,910,906,908,910,911,908,908,906,906,908,910,908,907,906,906,906,906,906,906,906,908,908,908,906,909,908,906,909,908,906,906,909,908,909,909,909,911,911,908,908,908,908,908,908,908,910,908,908,908,908,908,909,909,907,909,908,908,904,907,904,909,909,908,909,909,910,906,911,906,910,906,908,906,909,909,909,909,909,909,909,909,909,909,909,909,909,909,908,909,908,908,907,908,908,907,907,909,909,909,909,909,909,907,910,910,909,910,908,910,909,908,907,908,910,909,909,909,908,909,906,909,908,908,909,911,909,908,911,908,908,909,909,909,908,910,910,910,910,904,910,909,909,909,908,908,908,907,910,909,906,908,911,911,908,908,908,908,908,908,908,906,907,908,908,907,908,904,904,908,907,906,908,908,904,906,907,908,909,909,904,906,906,907,909,907,907,909,908,907,906,906,906,908,908,908,908,908,908,910,908,908,911,908,910,907,906,909,910,908,904,908,908,909,908,908,908,907,909,907,909,907,907,911,910,907,907,907,904,904,907,910,906,908,908,906,908,908,909,909,909,908,908,910,909,910,908,908,908,908,908,908,907,908,907,908,907,910,908,909,908,910,909,908,907,908,908,907,908,908,908,910,908,907,910,911,910,908,908,908,908,904,909,909,909,909,909,909,908,906,908,907,904,906,906,906,906,907,906,907,904,908,907,908,908,908,908,908,908,908,910,906,906,909,906,910,906,906,909,908,9 ...

# %%
fig_rr_avg = px.bar(route_region_summary.sort_values(by='Avg_Lead_Time'),
                    x='Route_Region', y='Avg_Lead_Time',
                    title='Average Shipping Lead Time by Route Region (Plotly)',
                    color='Route_Region', color_discrete_sequence=px.colors.qualitative.Vivid)
fig_rr_avg.update_layout(xaxis_tickangle=-45, plot_bgcolor='rgba(0,0,0,0)', paper_bgcolor='rgba(0,0,0,0)')
fig_rr_avg.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="35b755eb-cf18-43b3-888c-b756cd497ee6" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("35b755eb-cf18-43b3-888c-b756cd497ee6")) {                    Plotly.newPlot(                        "35b755eb-cf18-43b3-888c-b756cd497ee6",                        [{"alignmentgroup":"True","hovertemplate":"Route_Region=%{x}\u003cbr\u003eAvg_Lead_Time=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Factory → Canada - Atlantic","marker":{"color":"rgb(229, 134, 6)","pattern":{"shape":""}},"name":"Factory → Canada - Atlantic","offsetgroup":"Factory → Canada - Atlantic","orientation":"v","showlegend":true,"textposition":"auto","x":["Factory → Canada - Atlantic"],"xaxis":"x","y":[1275.9927536231885],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Route_Region=%{x}\u003cbr\u003eAvg_Lead_Time=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Factory → Canada - Pacific","marker":{"color":"rgb(93, 105, 177)","pattern":{"shape":""}},"name":"Factory → Canada - Pacific","offsetgroup":"Factory → Canada - Pacific","orientation":"v","showlegend":true,"textposition":"auto","x":["Factory → Canada - Pacific"],"xaxis":"x","y":[1288.54],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Route_Region=%{x}\u003cbr\u003eAvg_Lead_Time=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Factory → United States - Gulf","marker":{"color":"rgb(82, 188, 163)","pattern":{"shape":""}},"name":"Factory → United States - Gulf","offsetgroup":"Factory → United States - Gulf","orientation":"v","showlegend":true,"textposition":"auto","x":["Factory → United States - Gulf"],"xaxis":"x","y":[1311.3746913580246],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Route_Region=%{x}\u003cbr\u003eAvg_Lead_Time=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Factory → United States - Interior","marker":{"color":"rgb(153, 201, 69)","pattern":{"shape":""}},"name":"Factory → United States - Interior","offsetgroup":"Factory → United States - Interior","orientation":"v","showlegend":true,"textposition":"auto","x":["Factory → United States - Interior"],"xaxis":"x","y":[1322.4080929832114],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Route_Region=%{x}\u003cbr\u003eAvg_Lead_Time=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Factory → United States - Pacific","marker":{"color":"rgb(204, 97, 176)","pattern":{"shape":""}},"name":"Factory → United States - Pacific","offsetgroup":"Factory → United States - Pacific","orientation":"v","showlegend":true,"textposition":"auto","x":["Factory → United States - Pacific"],"xaxis":"x","y":[1322.7202622541367],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Route_Region=%{x}\u003cbr\u003eAvg_Lead_Time=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Factory → United States - Atlantic","marker":{"color":"rgb(36, 121, 108)","pattern":{"shape":""}},"name":"Factory → United States - Atlantic","offsetgroup":"Factory → United States - Atlantic","orientation":"v","showlegend":true,"textposition":"auto","x":["Factory → United States - Atlantic"],"xaxis":"x","y":[1325.010533707865],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Route_Region=%{x}\u003cbr\u003eAvg_Lead_Time=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Factory → Canada - Interior","marker":{"color":"rgb(218, 165, 27)","pattern":{"shape":""}},"name":"Factory → Canada - Interior","offsetgroup":"Factory → Canada - Interior","orientation":"v","showlegend":true,"textposition":"auto","x":["Factory → Canada - Interior"],"xaxis":"x","y":[1455.3333333333333],"yaxis":"y","type":"bar"}],                      ...

# %%
fig_delay = px.bar(congestion.head(10).reset_index(), x='State/Province', y='Delay_Frequency',
                   title='Top 10 States with Highest Delay Frequency (Plotly)',
                   color='State/Province', color_discrete_sequence=px.colors.qualitative.Vivid)
fig_delay.update_layout(xaxis_tickangle=-45, plot_bgcolor='rgba(0,0,0,0)', paper_bgcolor='rgba(0,0,0,0)')
fig_delay.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="b1798473-b1ac-4b8d-9bfe-53f3b8f12a61" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b1798473-b1ac-4b8d-9bfe-53f3b8f12a61")) {                    Plotly.newPlot(                        "b1798473-b1ac-4b8d-9bfe-53f3b8f12a61",                        [{"alignmentgroup":"True","hovertemplate":"State\u002fProvince=%{x}\u003cbr\u003eDelay_Frequency=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Alabama","marker":{"color":"rgb(229, 134, 6)","pattern":{"shape":""}},"name":"Alabama","offsetgroup":"Alabama","orientation":"v","showlegend":true,"textposition":"auto","x":["Alabama"],"xaxis":"x","y":[1.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"State\u002fProvince=%{x}\u003cbr\u003eDelay_Frequency=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Alberta","marker":{"color":"rgb(93, 105, 177)","pattern":{"shape":""}},"name":"Alberta","offsetgroup":"Alberta","orientation":"v","showlegend":true,"textposition":"auto","x":["Alberta"],"xaxis":"x","y":[1.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"State\u002fProvince=%{x}\u003cbr\u003eDelay_Frequency=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Arizona","marker":{"color":"rgb(82, 188, 163)","pattern":{"shape":""}},"name":"Arizona","offsetgroup":"Arizona","orientation":"v","showlegend":true,"textposition":"auto","x":["Arizona"],"xaxis":"x","y":[1.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"State\u002fProvince=%{x}\u003cbr\u003eDelay_Frequency=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Arkansas","marker":{"color":"rgb(153, 201, 69)","pattern":{"shape":""}},"name":"Arkansas","offsetgroup":"Arkansas","orientation":"v","showlegend":true,"textposition":"auto","x":["Arkansas"],"xaxis":"x","y":[1.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"State\u002fProvince=%{x}\u003cbr\u003eDelay_Frequency=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"British Columbia","marker":{"color":"rgb(204, 97, 176)","pattern":{"shape":""}},"name":"British Columbia","offsetgroup":"British Columbia","orientation":"v","showlegend":true,"textposition":"auto","x":["British Columbia"],"xaxis":"x","y":[1.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"State\u002fProvince=%{x}\u003cbr\u003eDelay_Frequency=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"California","marker":{"color":"rgb(36, 121, 108)","pattern":{"shape":""}},"name":"California","offsetgroup":"California","orientation":"v","showlegend":true,"textposition":"auto","x":["California"],"xaxis":"x","y":[1.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"State\u002fProvince=%{x}\u003cbr\u003eDelay_Frequency=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Colorado","marker":{"color":"rgb(218, 165, 27)","pattern":{"shape":""}},"name":"Colorado","offsetgroup":"Colorado","orientation":"v","showlegend":true,"textposition":"auto","x":["Colorado"],"xaxis":"x","y":[1.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"State\u002fProvince=%{x}\u003cbr\u003eDelay_Frequency=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Connecticut","marker":{"color":"rgb(47, 138, 196)","pattern":{"shape":""}},"name":"Connecticut","offsetgroup":"Connecticut","orientation":"v","showlegend":true,"textposition":"auto","x":["Connecticut"],"xaxis":"x","y":[1.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"State\u002fProvince=%{x}\u003cbr\u003eDelay_Frequency=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Delaware","marker":{"color":"rgb(118, 78, 159)","pattern":{"shape":""}},"name":" ...

# %%
# Visualizations
# Lead Time Distribution by Factory
fig_box = px.box(
    df, x="Factory", y="Shipping Lead Time", color="Factory",
    title="Lead Time Distribution per Factory",
    labels={"Shipping Lead Time": "Lead Time (days)"},
    color_discrete_sequence=px.colors.qualitative.Dark24
)
fig_box.update_layout(showlegend=False)
fig_box.show()

# Ship Mode Comparison
ship_mode_summary = df.groupby('Ship Mode').agg({
    'Shipping Lead Time': 'mean',
    'Ship Mode': 'count'
}).rename(columns={'Ship Mode': 'Shipments'}).reset_index()

fig_bar = px.bar(
    ship_mode_summary, x='Ship Mode', y='Shipments', color='Ship Mode',
    title='Shipment Volume by Ship Mode',
    color_discrete_sequence=px.colors.qualitative.Dark24
)
fig_bar.update_layout(showlegend=False)
fig_bar.show()

# Bottleneck States
volume = df.groupby('State/Province').size()
performance = df.groupby('State/Province')['Shipping Lead Time'].mean()
bottleneck_df = pd.DataFrame({
    'Volume': volume,
    'Avg_Lead_Time': performance
}).sort_values(by=['Volume', 'Avg_Lead_Time'], ascending=False).head(10)

print("=== Top Bottleneck States ===")
print(bottleneck_df)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="6d24a3a8-940d-4a24-8e7c-6ec69eade494" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("6d24a3a8-940d-4a24-8e7c-6ec69eade494")) {                    Plotly.newPlot(                        "6d24a3a8-940d-4a24-8e7c-6ec69eade494",                        [{"alignmentgroup":"True","hovertemplate":"Factory=%{x}\u003cbr\u003eLead Time (days)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Wicked Choccy's","marker":{"color":"#2E91E5"},"name":"Wicked Choccy's","notched":false,"offsetgroup":"Wicked Choccy's","orientation":"v","showlegend":true,"x":["Wicked Choccy's","Wicked Choccy's","Wicked Choccy's","Wicked Choccy's","Wicked Choccy's","Wicked Choccy's","Wicked Choccy's","Wicked Choccy's","Wicked Choccy's","Wicked Choccy's","Wicked Choccy's","Wicked Choccy's","Wicked Choccy's","Wicked Choccy's","Wicked Choccy's","Wicked Choccy's","Wicked Choccy's","Wicked Choccy's","Wicked Choccy's","Wicked Choccy's","Wicked Choccy's","Wicked Choccy's","Wicked Choccy's","Wicked Choccy's","Wicked Choccy's","Wicked Choccy's","Wicked Choccy's","Wicked Choccy's","Wicked Choccy's","Wicked Choccy's","Wicked Choccy's","Wicked Choccy's","Wicked Choccy's","Wicked Choccy's","Wicked Choccy's","Wicked Choccy's","Wicked Choccy's","Wicked Choccy's","Wicked Choccy's","Wicked Choccy's","Wicked Choccy's","Wicked Choccy's","Wicked Choccy's","Wicked Choccy's","Wicked Choccy's","Wicked Choccy's","Wicked Choccy's","Wicked Choccy's","Wicked Choccy's","Wicked Choccy's","Wicked Choccy's","Wicked Choccy's","Wicked Choccy's","Wicked Choccy's","Wicked Choccy's","Wicked Choccy's","Wicked Choccy's","Wicked Choccy's","Wicked Choccy's","Wicked Choccy's","Wicked Choccy's","Wicked Choccy's","Wicked Choccy's","Wicked Choccy's","Wicked Choccy's","Wicked Choccy's","Wicked Choccy's","Wicked Choccy's","Wicked Choccy's","Wicked Choccy's","Wicked Choccy's","Wicked Choccy's","Wicked Choccy's","Wicked Choccy's","Wicked Choccy's","Wicked Choccy's","Wicked Choccy's","Wicked Choccy's","Wicked Choccy's","Wicked Choccy's","Wicked Choccy's","Wicked Choccy's","Wicked Choccy's","Wicked Choccy's","Wicked Choccy's","Wicked Choccy's","Wicked Choccy's","Wicked Choccy's","Wicked Choccy's","Wicked Choccy's","Wicked Choccy's","Wicked Choccy's","Wicked Choccy's","Wicked Choccy's","Wicked Choccy's","Wicked Choccy's","Wicked Choccy's","Wicked Choccy's","Wicked Choccy's","Wicked Choccy's","Wicked Choccy's","Wicked Choccy's","Wicked Choccy's","Wicked Choccy's","Wicked Choccy's","Wicked Choccy's","Wicked Choccy's","Wicked Choccy's","Wicked Choccy's","Wicked Choccy's","Wicked Choccy's","Wicked Choccy's","Wicked Choccy's","Wicked Choccy's","Wicked Choccy's","Wicked Choccy's","Wicked Choccy's","Wicked Choccy's","Wicked Choccy's","Wicked Choccy's","Wicked Choccy's","Wicked Choccy's","Wicked Choccy's","Wicked Choccy's","Wicked Choccy's","Wicked Choccy's","Wicked Choccy's","Wicked Choccy's","Wicked Choccy's","Wicked Choccy's","Wicked Choccy's","Wicked Choccy's","Wicked Choccy's","Wicked Choccy's","Wicked Choccy's","Wicked Choccy's","Wicked Choccy's","Wicked Choccy's","Wicked Choccy's","Wicked Choccy's","Wicked Choccy's","Wicked Choccy's","Wicked Choccy's","Wicked Choccy's","Wicked Choccy's","Wicked Choccy's","Wicked Choccy's","Wicked Choccy's","Wicked Choccy's","Wicked Choccy's","Wicked Choccy's","Wicked Choccy's","Wicked Choccy's","Wicked Choccy's","Wicked Choccy's","Wicked Choccy's","Wicked Choccy's","Wicked Choccy's","Wicked Choccy's","Wicked Choccy's","Wicked Choccy's","Wicked Choccy's","Wicked Choccy's","Wicked Choccy's","Wicked Choccy's","Wicked Choccy's","Wicked Choccy's","Wicked Choccy's","Wicked Choccy's","Wicked Choccy's","Wicked Choccy's","Wicked Choccy's","Wicked Choccy's","Wicked Choccy's ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="36225f04-7dce-4193-af61-384e4fa2c9cf" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("36225f04-7dce-4193-af61-384e4fa2c9cf")) {                    Plotly.newPlot(                        "36225f04-7dce-4193-af61-384e4fa2c9cf",                        [{"alignmentgroup":"True","hovertemplate":"Ship Mode=%{x}\u003cbr\u003eShipments=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"First Class","marker":{"color":"#2E91E5","pattern":{"shape":""}},"name":"First Class","offsetgroup":"First Class","orientation":"v","showlegend":true,"textposition":"auto","x":["First Class"],"xaxis":"x","y":[1548],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Ship Mode=%{x}\u003cbr\u003eShipments=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Same Day","marker":{"color":"#E15F99","pattern":{"shape":""}},"name":"Same Day","offsetgroup":"Same Day","orientation":"v","showlegend":true,"textposition":"auto","x":["Same Day"],"xaxis":"x","y":[547],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Ship Mode=%{x}\u003cbr\u003eShipments=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Second Class","marker":{"color":"#1CA71C","pattern":{"shape":""}},"name":"Second Class","offsetgroup":"Second Class","orientation":"v","showlegend":true,"textposition":"auto","x":["Second Class"],"xaxis":"x","y":[1979],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Ship Mode=%{x}\u003cbr\u003eShipments=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Standard Class","marker":{"color":"#FB0D0D","pattern":{"shape":""}},"name":"Standard Class","offsetgroup":"Standard Class","orientation":"v","showlegend":true,"textposition":"auto","x":["Standard Class"],"xaxis":"x","y":[6120],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0 ...
# === Top Bottleneck States ===
#                 Volume  Avg_Lead_Time
# State/Province
# California        2001    1318.427286
# New York          1128    1324.493794
# Texas              985    1310.305584
# Pennsylvania       587    1324.199319
# Washington         506    1360.662055
# Illinois           492    1323.150407
# Ohio               469    1325.733475
# Florida            383    1311.396867
# Michigan           255    1300.560784
# North Carolina     249    1334.883534
